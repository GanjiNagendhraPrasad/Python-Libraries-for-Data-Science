# %% [markdown]
# #pandas

# %% [markdown]
# Pandas is used on excel data for data cleaning and data transformation

# %%
import pandas as pd
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
len(dir(pd))
# Out:
# 141

# %% [markdown]
# #series

# %%
import numpy as np
import pandas as pd

a=np.array([23,55,98,12,45])
b=pd.Series(a)
b
# Out:
# 0    23
# 1    55
# 2    98
# 3    12
# 4    45
# dtype: int64

# %%
b=pd.Series(a,index=['r1','r2','r3','r4','r5'])
b
# Out:
# r1    23
# r2    55
# r3    98
# r4    12
# r5    45
# dtype: int64

# %%
b['r3']
# Out:
# np.int64(98)

# %%
b[2]
# Out:
# np.int64(98)

# %%
import warnings
warnings.filterwarnings('ignore')
b[2]
# Out:
# np.int64(98)

# %% [markdown]
# #DataFrame

# %%
a={'Name':['jonh','petter','steve','brad','smit','hasan'],
   'Location':['usa','uk','canada','india','paries','dubai'],
   'Age':[20,21,25,29,32,34],
   'company':['google','meta','IBM','msft','wipro','delloite'],
   'salary':[1200,1400,1500,1900,2400,4500]
   }
print(a)
# Out:
# {'Name': ['jonh', 'petter', 'steve', 'brad', 'smit', 'hasan'], 'Location': ['usa', 'uk', 'canada', 'india', 'paries', 'dubai'], 'Age': [20, 21, 25, 29, 32, 34], 'company': ['google', 'meta', 'IBM', 'msft', 'wipro', 'delloite'], 'salary': [1200, 1400, 1500, 1900, 2400, 4500]}

# %%
b=pd.DataFrame(a)
b
# Out:
#      Name Location  Age   company  salary
# 0    jonh      usa   20    google    1200
# 1  petter       uk   21      meta    1400
# 2   steve   canada   25       IBM    1500
# 3    brad    india   29      msft    1900
# 4    smit   paries   32     wipro    2400
# 5   hasan    dubai   34  delloite    4500

# %%
b=pd.DataFrame(a,index=['r1','r2','r3','r4','r5','r6'])
b
# Out:
#       Name Location  Age   company  salary
# r1    jonh      usa   20    google    1200
# r2  petter       uk   21      meta    1400
# r3   steve   canada   25       IBM    1500
# r4    brad    india   29      msft    1900
# r5    smit   paries   32     wipro    2400
# r6   hasan    dubai   34  delloite    4500

# %%
b['company']['r3']
# Out:
# 'IBM'

# %%
b['Age']['r5']
# Out:
# np.int64(32)

# %%
b['Location']['r5']='china'
b
# Out:
#       Name Location  Age   company  salary
# r1    jonh      usa   20    google    1200
# r2  petter       uk   21      meta    1400
# r3   steve   canada   25       IBM    1500
# r4    brad    india   29      msft    1900
# r5    smit    china   32     wipro    2400
# r6   hasan    dubai   34  delloite    4500

# %% [markdown]
# #shape

# %%
b.shape
# Out:
# (6, 5)

# %% [markdown]
# #size

# %%
b.size
# Out:
# 30

# %%
#loc
b.loc['r2':'r4','Location':'company']   # here no n-1 logic
# Out:
#    Location  Age company
# r2       uk   21    meta
# r3   canada   25     IBM
# r4    india   29    msft

# %%
#iloc
b.iloc[1:4,1:4]   # here n-1 logic
# Out:
#    Location  Age company
# r2       uk   21    meta
# r3   canada   25     IBM
# r4    india   29    msft

# %%
b.loc['r3':'r4','Name':'company']
# Out:
#      Name Location  Age company
# r3  steve   canada   25     IBM
# r4   brad    india   29    msft

# %%
b.iloc[2:4,0:4]
# Out:
#      Name Location  Age company
# r3  steve   canada   25     IBM
# r4   brad    india   29    msft

# %%
b.loc['r2':'r5','Location':'company']
# Out:
#    Location  Age company
# r2       uk   21    meta
# r3   canada   25     IBM
# r4    india   29    msft
# r5    china   32   wipro

# %%
b.iloc[1:5,1:4]
# Out:
#    Location  Age company
# r2       uk   21    meta
# r3   canada   25     IBM
# r4    india   29    msft
# r5    china   32   wipro

# %%
b.iloc[:,1:3]
# Out:
#    Location  Age
# r1      usa   20
# r2       uk   21
# r3   canada   25
# r4    india   29
# r5    china   32
# r6    dubai   34

# %%
#columns
b.columns
# Out:
# Index(['Name', 'Location', 'Age', 'company', 'salary'], dtype='object')

# %%
b.index
# Out:
# Index(['r1', 'r2', 'r3', 'r4', 'r5', 'r6'], dtype='object')

# %%
b['Age']=[1,2,3,4,5,6]  # override with new values
b
# Out:
#       Name Location  Age   company  salary
# r1    jonh      usa    1    google    1200
# r2  petter       uk    2      meta    1400
# r3   steve   canada    3       IBM    1500
# r4    brad    india    4      msft    1900
# r5    smit    china    5     wipro    2400
# r6   hasan    dubai    6  delloite    4500

# %%
b['Tax']=[10,20,50,60,70,5]  # new column created
b
# Out:
#       Name Location  Age   company  salary  Tax
# r1    jonh      usa    1    google    1200   10
# r2  petter       uk    2      meta    1400   20
# r3   steve   canada    3       IBM    1500   50
# r4    brad    india    4      msft    1900   60
# r5    smit    china    5     wipro    2400   70
# r6   hasan    dubai    6  delloite    4500    5

# %% [markdown]
# #NULL

# %%
b['TDS']=[150,160,np.nan,200,np.nan,250]  # null are created
b
# Out:
#       Name Location  Age   company  salary  Tax    TDS
# r1    jonh      usa    1    google    1200   10  150.0
# r2  petter       uk    2      meta    1400   20  160.0
# r3   steve   canada    3       IBM    1500   50    NaN
# r4    brad    india    4      msft    1900   60  200.0
# r5    smit    china    5     wipro    2400   70    NaN
# r6   hasan    dubai    6  delloite    4500    5  250.0

# %% [markdown]
# #dropna

# %%
 # b.dropna()

# %% [markdown]
# #fillna

# %%
b['TDS']=b['TDS'].fillna(120)  # null's is filled with 120
b
# Out:
#       Name Location  Age   company  salary  Tax    TDS
# r1    jonh      usa    1    google    1200   10  150.0
# r2  petter       uk    2      meta    1400   20  160.0
# r3   steve   canada    3       IBM    1500   50  120.0
# r4    brad    india    4      msft    1900   60  200.0
# r5    smit    china    5     wipro    2400   70  120.0
# r6   hasan    dubai    6  delloite    4500    5  250.0

# %% [markdown]
# #drop

# %%
b=b.drop(['Age'],axis=1)  # age column removed
b
# Out:
#       Name Location   company  salary  Tax    TDS
# r1    jonh      usa    google    1200   10  150.0
# r2  petter       uk      meta    1400   20  160.0
# r3   steve   canada       IBM    1500   50  120.0
# r4    brad    india      msft    1900   60  200.0
# r5    smit    china     wipro    2400   70  120.0
# r6   hasan    dubai  delloite    4500    5  250.0

# %%
b.drop(['r6'],axis=0)  # r6 row removed
# Out:
#       Name Location company  salary  Tax    TDS
# r1    jonh      usa  google    1200   10  150.0
# r2  petter       uk    meta    1400   20  160.0
# r3   steve   canada     IBM    1500   50  120.0
# r4    brad    india    msft    1900   60  200.0
# r5    smit    china   wipro    2400   70  120.0

# %%
b.drop(['r5'],axis=0)
# Out:
#       Name Location   company  salary  Tax    TDS
# r1    jonh      usa    google    1200   10  150.0
# r2  petter       uk      meta    1400   20  160.0
# r3   steve   canada       IBM    1500   50  120.0
# r4    brad    india      msft    1900   60  200.0
# r6   hasan    dubai  delloite    4500    5  250.0

# %%
b
# Out:
#       Name Location   company  salary  Tax    TDS
# r1    jonh      usa    google    1200   10  150.0
# r2  petter       uk      meta    1400   20  160.0
# r3   steve   canada       IBM    1500   50  120.0
# r4    brad    india      msft    1900   60  200.0
# r5    smit    china     wipro    2400   70  120.0
# r6   hasan    dubai  delloite    4500    5  250.0

# %% [markdown]
# #rename

# %%
b=b.rename(columns={'Tax':'Income_Tax'})
b
# Out:
#       Name Location   company  salary  Income_Tax    TDS
# r1    jonh      usa    google    1200          10  150.0
# r2  petter       uk      meta    1400          20  160.0
# r3   steve   canada       IBM    1500          50  120.0
# r4    brad    india      msft    1900          60  200.0
# r5    smit    china     wipro    2400          70  120.0
# r6   hasan    dubai  delloite    4500           5  250.0

# %% [markdown]
# # saving file in to excel sheet

# %% [markdown]
# to_csv

# %%
b.to_csv('Own_data.csv')

# %% [markdown]
# removing index values

# %%
b.to_csv('Own_data.csv',index=False)

# %% [markdown]
# #Loading excel sheet

# %% [markdown]
# read_csv

# %%
df=pd.read_csv('/content/Titanic-Dataset.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 174          175         0       1     Smith, Mr. James Clinch    male  56.0
# 205          206         0       3  Strom, Miss. Telma Matilda  female   2.0
# 419          420         0       3   Van Impe, Miss. Catharina  female  10.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 174      0      0   17764  30.6958    A7        C
# 205      0      1  347054  10.4625    G6        S
# 419      0      2  345773  24.1500   NaN        S

# %%
tc=df.select_dtypes(include='object')
tc
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
num_cols=df.select_dtypes(exclude='object')
num_cols
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
df=df.drop(['PassengerId','Name','Ticket'],axis=1)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0           0       3    male  22.0      1      0   7.2500   NaN        S
# 1           1       1  female  38.0      1      0  71.2833   C85        C
# 2           1       3  female  26.0      0      0   7.9250   NaN        S
# 3           1       1  female  35.0      1      0  53.1000  C123        S
# 4           0       3    male  35.0      0      0   8.0500   NaN        S
# ..        ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886         0       2    male  27.0      0      0  13.0000   NaN        S
# 887         1       1  female  19.0      0      0  30.0000   B42        S
# 888         0       3  female   NaN      1      2  23.4500   NaN        S
# 889         1       1    male  26.0      0      0  30.0000  C148        C
# 890         0       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 9 columns]

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (183, 9)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare        Cabin  \
# 1           1       1  female  38.0      1      0  71.2833          C85
# 3           1       1  female  35.0      1      0  53.1000         C123
# 6           0       1    male  54.0      0      0  51.8625          E46
# 10          1       3  female   4.0      1      1  16.7000           G6
# 11          1       1  female  58.0      0      0  26.5500         C103
# ..        ...     ...     ...   ...    ...    ...      ...          ...
# 871         1       1  female  47.0      1      1  52.5542          D35
# 872         0       1    male  33.0      0      0   5.0000  B51 B53 B55
# 879         1       1  female  56.0      0      1  83.1583          C50
# 887         1       1  female  19.0      0      0  30.0000          B42
# 889         1       1    male  26.0      0      0  30.0000         C148
#
#     Embarked
# 1          C
# 3          S
# 6          S
# 10         S
# 11         S
# ..       ...
# ...

# %%
df.to_csv('Titanic_cleaned_data.csv',index=False)
